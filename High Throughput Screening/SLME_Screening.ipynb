# %%
import pandas as pd

# 读取表格数据
df = pd.read_csv("Bg_Screening.csv")
df
# Out:
#                             Formula  Octahedral factor  Tolerance factor  \
# 0                          MAGeCl_3               0.48              1.05
# 1                           MASnI_3               0.52              0.92
# 2                          MASnBr_3               0.59              0.94
# 3                          MASnCl_3               0.64              0.95
# 4                           MASnF_3               0.86              1.00
# ...                             ...                ...               ...
# 21849  FAPb_0.375Ge_0.625I_1.5F_1.5               0.56              1.10
# 21850  FAPb_0.375Sn_0.625I_1.5F_1.5               0.66              1.04
# 21851      FAGe_0.5Sn_0.5I_1.5F_1.5               0.57              1.09
# 21852      FAGe_0.5Pb_0.5I_1.5F_1.5               0.58              1.09
# 21853      FASn_0.5Pb_0.5I_1.5F_1.5               0.66              1.03
#
#             Dec        Bg      SLME  K_frac  Rb_frac  Cs_frac  MA_frac  ...  \
# ...

# %%
# 根据条件筛选数据
filtered_df = df[(df['SLME'] > 0.2)]
filtered_df
# Out:
#                                  Formula  Octahedral factor  Tolerance factor  \
# 1                                MASnI_3               0.52              0.92
# 8                                FASnI_3               0.52              1.00
# 9                               FASnBr_3               0.59              1.02
# 22                               CsPbI_3               0.54              0.82
# 95                 Li_0.125FA_0.875SnI_3               0.52              0.95
# ...                                  ...                ...               ...
# 20307  FAGe_0.125Sn_0.875Cl_0.375I_2.625               0.52              1.01
# 20402  FACa_0.125Sn_0.875Br_0.375I_2.625               0.52              1.01
# 20411  FAPb_0.125Sn_0.875Br_0.375I_2.625               0.53              1.00
# 20427    FAPb_0.25Sn_0.75Br_0.375I_2.625               0.53              1.00
# 20859    FAGe_0.125Sn_0.875Br_0.75I_2.25               0.52              1.01
#
# ...

# %%
# 保存筛选后的数据为新的表格文件
filtered_df.to_csv("SLME_Screening.csv", index=False)

# %%
# 根据条件筛选数据
filtered_df = df[(df['SLME'] > 0.23)]
filtered_df
# Out:
#                                   Formula  Octahedral factor  \
# 374                 MABa_0.125Sn_0.875I_3               0.54
# 7158     K_0.25FA_0.75Ba_0.125Sn_0.875I_3               0.54
# 7164    FA_0.25MA_0.75Ba_0.125Sn_0.875I_3               0.54
# 7167  Cs_0.375FA_0.625Ba_0.125Sn_0.875I_3               0.54
#
#       Tolerance factor       Dec        Bg      SLME  K_frac  Rb_frac  \
# 374               0.91 -0.056387  1.110747  0.230976    0.00      0.0
# 7158              0.94 -0.200773  1.242298  0.230210    0.25      0.0
# 7164              0.93 -0.245807  1.145758  0.230210    0.00      0.0
# 7167              0.93 -0.303581  1.309949  0.230087    0.00      0.0
#
#       Cs_frac  MA_frac  ...  Ba_frac  Ge_frac  Sn_frac  Pb_frac  Be_frac  \
# 374     0.000     1.00  ...    0.125      0.0    0.875      0.0      0.0
# 7158    0.000     0.00  ...    0.125      0.0    0.875      0.0      0.0
# 7164    0.000     0.75  ...    0.125      0.0    0.875      0.0      0.0
# ...

# %%
# 保存筛选后的数据为新的表格文件
filtered_df.to_csv("SLME23_Screening.csv", index=False)
